# %%
import folium
world_map = folium.Map()
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
amalapuram=folium.Map(location=[16.5775,82.0031])
amalapuram
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
nuzvid=folium.Map(location=[16.7850,80.8488])
nuzvid
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
from branca.element import Figure
fig=Figure(width=550,height=350)
map1=folium.Map(location=[16.5775,82.0031],zoom_start=12,min_zoom=8,max_zoom=14)
fig.add_child(map1)
map1
fig2=Figure(width=850,height=550)
map2=folium.Map(location=[16.5775,82.0031])
fig2.add_child(map2)
folium.TileLayer('Stamen Terrain').add_to(map2)
folium.TileLayer('Stamen Toner').add_to(map2)
folium.TileLayer('Stamen Water Color').add_to(map2)
folium.TileLayer('cartodbpositron').add_to(map2)
folium.TileLayer('cartodbdark_matter').add_to(map2)
folium.LayerControl().add_to(map2)
map2
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...

# %%
cord=[[16.7850,80.8488],[16.6356,80.9716],[16.7107,81.0952],[16.7566,81.6770],[16.7625,81.8423],[16.5775,82.0031]]
fig3=Figure(height=550,width=750)
map3=folium.Map(location=[16.7850,80.8488],zoom_start=12,max_zoom=14)
fig.add_child(map1)
map1
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import folium
from branca.element import Figure
fig234=Figure(height=550,width=750)
map9=folium.Map(location=[16.768802981676966, 80.85156345374226],tiles='cartodbpositron',zoom_start=12)
fig234.add_child(map9)
map9
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...

# %%
coords_12=[[16.681647869590893, 80.9467957496078],[16.886754611626067, 81.29835822504413],[16.960328488235906, 81.43568731701144],
           [17.012863630005842, 81.75429081037561],[16.865728229329047, 81.8257019381986],[16.755301398085205, 81.88063357498554],
           [16.70795596527804, 81.92457888441507]]
coords_23=[[16.80263505515022, 80.84791880339134],[16.718478188719867, 80.91932993121434],[16.73426043555245, 81.04567269582427],[16.750041375420587, 81.1006043326112],
           [16.781599329908634, 81.20497444250634],[16.8184103189299, 81.32582404343759],[16.844699507435376, 81.55104375426397],[16.760561275370254, 81.6828796825526],
           [16.713217149527406, 81.7597839740543],[16.713217149527406, 81.85866092027076],[16.676385815848064, 81.94105837545115],[16.58164413126191, 81.99049684855939]]

# %%
f7=folium.FeatureGroup("vehicle 1")
f8=folium.FeatureGroup("vehicle 2")

# %%
#Adding markers to the map
folium.Marker(location=[16.781599329908634, 80.85890513074874],popup='Default popup Marker1',tooltip='University',icon=folium.Icon(color='red',prefix='fa',icon='University')).add_to(map9)
folium.Marker(location=[16.718478188719867, 80.91383676753566],popup='<strong>Marker2</strong>',tooltip='<strong>Home</strong>',icon=folium.Icon(color='aqua',prefix='fa',icon='home')).add_to(map9)
folium.Marker(location=[16.718478188719867, 81.0291932047882],popup='<h3 style="color:green;">Marker3</h3>',tooltip='<strong>Hospoital</strong>',icon=folium.Icon(color='green',prefix='fa',icon='medkat')).add_to(map9)
folium.Marker(location=[16.771080593640413, 81.15553596939812],popup='<h3 style="color:green;">Marker4</h3>',tooltip='<strong>shopping mall</strong>',icon=folium.Icon(color='purple',prefix='fa',icon='shopping-bag')).add_to(map9)
folium.Marker(location=[16.80263505515022, 81.26539924297197],popup='<h3 style="color:blue;">Marker7</h3>',tooltip='<strong>bus stand</strong>',icon=folium.Icon(color='blue',prefix='fa',icon='bus')).add_to(map9)
folium.Marker(location=[16.750041375420587, 81.11708382364728],popup='<h3 style="color:green;">Marker8</h3>',tooltip='<strong>clinic</strong>',icon=folium.Icon(color='orange',prefix='fa',icon='medkat')).add_to(map9)
folium.Marker(location=[16.755301398085205, 81.1665222967555],popup='<h3 style="color:green;">Marker9</h3>',tooltip='<strong>Railway station</strong>',icon=folium.Icon(color='red',prefix='fa',icon='subway')).add_to(map9)
folium.Marker(location=[16.8184103189299, 81.23793342457851],popup='<h3 style="color:red;">Marker10</h3>',tooltip='<strong>temple</strong>',icon=folium.Icon(color='black',prefix='fa',icon='ship')).add_to(map9)
folium.Marker(location=[16.80263505515022, 81.6059753910509],popup='<h3 style="color:green;">Marker11</h3>',tooltip='<strong>bus stand</strong>',icon=folium.Icon(color='blue',prefix='fa',icon='bus')).add_to(map9)
folium.Marker(location=[16.750041375420587, 81.71034550094606],popup='<h3 style="color:green;">Marker12</h3>',tooltip='<strong>car showroom</strong>',icon=folium.Icon(color='brown',prefix='fa',icon='car')).add_to(map9)
folium.Marker(location=[16.686909778519098, 81.9026062297003],popup='<h3 style="color:blue;">Marker13</h3>',tooltip='<strong>Ramana studio</strong>',icon=folium.Icon(color='grey',prefix='fa',icon='camera')).add_to(map9)
folium.Marker(location=[16.634284177428416, 81.9850036848807],popup='<h3 style="color:green;">Marker14</h3>',tooltip='<strong>TEMPLE</strong>',icon=folium.Icon(color='orange',prefix='fa',icon='ship')).add_to(map9)
map1
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: color argument of Icon should be one of: {'green', 'darkred', 'black', 'gray', 'cadetblue', 'darkblue', 'white', 'darkgreen', 'lightblue', 'purple', 'lightgray', 'red', 'pink', 'lightred', 'orange', 'darkpurple', 'beige', 'lightgreen', 'blue'}.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: UserWarning: color argument of Icon should be one of: {'green', 'darkred', 'black', 'gray', 'cadetblue', 'darkblue', 'white', 'darkgreen', 'lightblue', 'purple', 'lightgray', 'red', 'pink', 'lightred', 'orange', 'darkpurple', 'beige', 'lightgreen', 'blue'}.
#   # This is added back by InteractiveShellApp.init_path()
# ...

# %%
# Adding lines to the different feature groups
line_1=folium.vector_layers.PolyLine(coords_12,popup='<b>Path of Vehicle_1</b>',tooltip='Vehicle_1',color='blue',weight=10).add_to(f7)
line_2=folium.vector_layers.PolyLine(coords_23,popup='<b>Path of Vehicle_2</b>',tooltip='Vehicle_2',color='red',weight=10).add_to(f8)
line_2=folium.vector_layers.PolyLine(coords_23,popup='<b>Path of Vehicle_2</b>',tooltip='Vehicle_3',color='red',weight=10).add_to(f8)
f7.add_to(map9)
f8.add_to(map9)
folium.LayerControl().add_to(map9)
map9
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...
